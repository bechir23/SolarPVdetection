# %%
# !pip install -q supervision
# !pip install ultralytics
# !pip install -q git+https://github.com/THU-MIG/yolov10.git
# !pip install huggingface_hub
# Out:
# [notice] A new release of pip is available: 24.1.1 -> 24.1.2
# [notice] To update, run: pip install --upgrade pip
# Collecting ultralytics
#   Downloading ultralytics-8.2.59-py3-none-any.whl.metadata (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.2/41.2 kB 9.0 MB/s eta 0:00:00
# Collecting numpy<2.0.0,>=1.23.0 (from ultralytics)
#   Downloading numpy-1.26.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 13.2 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib>=3.3.0 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (3.8.4)
# Collecting opencv-python>=4.6.0 (from ultralytics)
#   Downloading opencv_python-4.10.0.84-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Requirement already satisfied: pillow>=7.1.2 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (10.3.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (6.0.1)
# Requirement already satisfied: requests>=2.23.0 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (2.31.0)
# Requirement already satisfied: scipy>=1.4.1 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (1.14.0)
# Collecting torch>=1.8.0 (from ultralytics)
#   Downloading torch-2.3.1-cp310-cp310-manylinux1_x86_64.whl.metadata (26 kB)
# Collecting torchvision>=0.9.0 (from ultralytics)
#   Downloading torchvision-0.18.1-cp310-cp310-manylinux1_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: tqdm>=4.64.0 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (4.66.2)
# Requirement already satisfied: psutil in /opt/conda/lib/python3.10/site-packages (from ultralytics) (6.0.0)
# Collecting py-cpuinfo (from ultralytics)
#   Downloading py_cpuinfo-9.0.0-py3-none-any.whl.metadata (794 bytes)
# Requirement already satisfied: pandas>=1.1.4 in /opt/conda/lib/python3.10/site-packages (from ultralytics) (2.2.2)
# Collecting seaborn>=0.11.0 (from ultralytics)
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting ultralytics-thop>=2.0.0 (from ultralytics)
#   Downloading ultralytics_thop-2.0.0-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (24.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.1.4->ultralytics) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.1.4->ultralytics) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests>=2.23.0->ultralytics) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests>=2.23.0->ultralytics) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests>=2.23.0->ultralytics) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests>=2.23.0->ultralytics) (2024.6.2)
# Collecting filelock (from torch>=1.8.0->ultralytics)
#   Downloading filelock-3.15.4-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: typing-extensions>=4.8.0 in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (4.12.2)
# Collecting sympy (from torch>=1.8.0->ultralytics)
#   Downloading sympy-1.13.0-py3-none-any.whl.metadata (12 kB)
# Collecting networkx (from torch>=1.8.0->ultralytics)
#   Downloading networkx-3.3-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics) (3.1.4)
# Collecting fsspec (from torch>=1.8.0->ultralytics)
#   Downloading fsspec-2024.6.1-py3-none-any.whl.metadata (11 kB)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nccl-cu12==2.20.5 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch>=1.8.0->ultralytics)
#   Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.7 kB)
# Collecting triton==2.3.1 (from torch>=1.8.0->ultralytics)
#   Downloading triton-2.3.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.4 kB)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.8.0->ultralytics)
#   Downloading nvidia_nvjitlink_cu12-12.5.82-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch>=1.8.0->ultralytics) (2.1.5)
# Collecting mpmath<1.4,>=1.1.0 (from sympy->torch>=1.8.0->ultralytics)
#   Downloading mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Downloading ultralytics-8.2.59-py3-none-any.whl (802 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 802.9/802.9 kB 60.9 MB/s eta 0:00:00
# Downloading numpy-1.26.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 130.0 MB/s eta 0:00:0000:010:01
# Downloading opencv_python-4.10.0.84-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (62.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.5/62.5 MB 87.2 MB/s eta 0:00:00:00:0100:01
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 kB 62.9 MB/s eta 0:00:00
# Downloading torch-2.3.1-cp310-cp310-manylinux1_x86_64.whl (779.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 779.1/779.1 MB 10.8 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 19.0 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 146.0 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 112.6 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 96.8 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 11.4 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 47.2 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 37.6 MB/s eta 0:00:0000:0100:01m
# Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 44.7 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 35.0 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 176.2/176.2 MB 37.8 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 27.7 MB/s eta 0:00:00
# Downloading triton-2.3.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (168.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 168.1/168.1 MB 39.6 MB/s eta 0:00:0000:0100:01
# Downloading torchvision-0.18.1-cp310-cp310-manylinux1_x86_64.whl (7.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 175.8 MB/s eta 0:00:0000:01
# Downloading ultralytics_thop-2.0.0-py3-none-any.whl (25 kB)
# Downloading py_cpuinfo-9.0.0-py3-none-any.whl (22 kB)
# Downloading filelock-3.15.4-py3-none-any.whl (16 kB)
# Downloading fsspec-2024.6.1-py3-none-any.whl (177 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 177.6/177.6 kB 26.7 MB/s eta 0:00:00
# Downloading networkx-3.3-py3-none-any.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 117.3 MB/s eta 0:00:00
# Downloading sympy-1.13.0-py3-none-any.whl (6.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 116.7 MB/s eta 0:00:00a 0:00:01
# Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 96.5 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.5.82-py3-none-manylinux2014_x86_64.whl (21.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 132.4 MB/s eta 0:00:0000:0100:01
# Installing collected packages: py-cpuinfo, mpmath, sympy, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, numpy, networkx, fsspec, filelock, triton, opencv-python, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, torch, seaborn, ultralytics-thop, torchvision, ultralytics
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.0
#     Uninstalling numpy-2.0.0:
#       Successfully uninstalled numpy-2.0.0
# Successfully installed filelock-3.15.4 fsspec-2024.6.1 mpmath-1.3.0 networkx-3.3 numpy-1.26.4 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.20.5 nvidia-nvjitlink-cu12-12.5.82 nvidia-nvtx-cu12-12.1.105 opencv-python-4.10.0.84 py-cpuinfo-9.0.0 seaborn-0.13.2 sympy-1.13.0 torch-2.3.1 torchvision-0.18.1 triton-2.3.1 ultralytics-8.2.59 ultralytics-thop-2.0.0
#
# [notice] A new release of pip is available: 24.1.1 -> 24.1.2
# [notice] To update, run: pip install --upgrade pip
#
# [notice] A new release of pip is available: 24.1.1 -> 24.1.2
# [notice] To update, run: pip install --upgrade pip
# Collecting huggingface_hub
#   Downloading huggingface_hub-0.23.5-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from huggingface_hub) (3.15.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/conda/lib/python3.10/site-packages (from huggingface_hub) (2024.6.1)
# Requirement already satisfied: packaging>=20.9 in /opt/conda/lib/python3.10/site-packages (from huggingface_hub) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.10/site-packages (from huggingface_hub) (6.0.1)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from huggingface_hub) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /opt/conda/lib/python3.10/site-packages (from huggingface_hub) (4.66.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.10/site-packages (from huggingface_hub) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface_hub) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface_hub) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface_hub) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface_hub) (2024.6.2)
# Downloading huggingface_hub-0.23.5-py3-none-any.whl (402 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 402.8/402.8 kB 31.3 MB/s eta 0:00:00
# Installing collected packages: huggingface_hub
# Successfully installed huggingface_hub-0.23.5
#
# [notice] A new release of pip is available: 24.1.1 -> 24.1.2
# [notice] To update, run: pip install --upgrade pip

# %%
import os

os.environ['WANDB_MODE'] = 'disabled'
os.environ["OMP_NUM_THREADS"] = "16"

# %%
# !yolo task=detect mode=train batch=128 epochs=100 workers=8 model='ELSOLAR-3/yolov10m.pt' data='/work/ELSOLAR-3/data.yaml' device=0,1,2,3
# Out:
# New https://pypi.org/project/ultralytics/8.2.59 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.1.34 🚀 Python-3.10.14 torch-2.3.1+cu121 CUDA:0 (Tesla V100-SXM2-32GB, 32494MiB)
#                                                             CUDA:1 (Tesla V100-SXM2-32GB, 32494MiB)
#                                                             CUDA:2 (Tesla V100-SXM2-32GB, 32494MiB)
#                                                             CUDA:3 (Tesla V100-SXM2-32GB, 32494MiB)
# engine/trainer: task=detect, mode=train, model=ELSOLAR-3/yolov10m.pt, data=/work/ELSOLAR-3/data.yaml, epochs=100, time=None, patience=100, batch=128, imgsz=640, save=True, save_period=-1, val_period=1, cache=False, device=(0, 1, 2, 3), workers=8, project=None, name=train4, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, bgr=0.0, mosaic=1.0, mixup=0.0, copy_paste=0.0, auto_augment=randaugment, erasing=0.4, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=runs/detect/train4
# Overriding model.yaml nc=80 with nc=14
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      1392  ultralytics.nn.modules.conv.Conv             [3, 48, 3, 2]
#   1                  -1  1     41664  ultralytics.nn.modules.conv.Conv             [48, 96, 3, 2]
#   2                  -1  2    111360  ultralytics.nn.modules.block.C2f             [96, 96, 2, True]
#   3                  -1  1    166272  ultralytics.nn.modules.conv.Conv             [96, 192, 3, 2]
#   4                  -1  4    813312  ultralytics.nn.modules.block.C2f             [192, 192, 4, True]
#   5                  -1  1     78720  ultralytics.nn.modules.block.SCDown          [192, 384, 3, 2]
#   6                  -1  4   3248640  ultralytics.nn.modules.block.C2f             [384, 384, 4, True]
#   7                  -1  1    228672  ultralytics.nn.modules.block.SCDown          [384, 576, 3, 2]
#   8                  -1  2   1689984  ultralytics.nn.modules.block.C2fCIB          [576, 576, 2, True]
#   9                  -1  1    831168  ultralytics.nn.modules.block.SPPF            [576, 576, 5]
#  10                  -1  1   1253088  ultralytics.nn.modules.block.PSA             [576, 576]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  2   1993728  ultralytics.nn.modules.block.C2f             [960, 384, 2]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  2    517632  ultralytics.nn.modules.block.C2f             [576, 192, 2]
#  17                  -1  1    332160  ultralytics.nn.modules.conv.Conv             [192, 192, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  2    831744  ultralytics.nn.modules.block.C2fCIB          [576, 384, 2, True]
#  20                  -1  1    152448  ultralytics.nn.modules.block.SCDown          [384, 384, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  2   1911168  ultralytics.nn.modules.block.C2fCIB          [960, 576, 2, True]
#  23        [16, 19, 22]  1   2297188  ultralytics.nn.modules.head.v10Detect        [14, [192, 384, 576]]
# YOLOv10m summary: 498 layers, 16500340 parameters, 16500324 gradients, 64.1 GFLOPs
#
# Transferred 787/799 items from pretrained weights
# DDP: debug command /opt/conda/bin/python3.10 -m torch.distributed.run --nproc_per_node 4 --master_port 54987 /home/ucloud/.config/yolov10/DDP/_temp_m_gkuz51139753221081840.py
# [W Utils.hpp:166] Warning: Environment variable NCCL_BLOCKING_WAIT is deprecated; use TORCH_NCCL_BLOCKING_WAIT instead (function getCvarBool)
# Ultralytics YOLOv8.1.34 🚀 Python-3.10.14 torch-2.3.1+cu121 CUDA:0 (Tesla V100-SXM2-32GB, 32494MiB)
#                                                             CUDA:1 (Tesla V100-SXM2-32GB, 32494MiB)
#                                                             CUDA:2 (Tesla V100-SXM2-32GB, 32494MiB)
#                                                             CUDA:3 (Tesla V100-SXM2-32GB, 32494MiB)
# [W Utils.hpp:166] Warning: Environment variable NCCL_BLOCKING_WAIT is deprecated; use TORCH_NCCL_BLOCKING_WAIT instead (function getCvarBool)
# [W Utils.hpp:166] Warning: Environment variable NCCL_BLOCKING_WAIT is deprecated; use TORCH_NCCL_BLOCKING_WAIT instead (function getCvarBool)
# [W Utils.hpp:166] Warning: Environment variable NCCL_BLOCKING_WAIT is deprecated; use TORCH_NCCL_BLOCKING_WAIT instead (function getCvarBool)
# Overriding model.yaml nc=80 with nc=14
# Transferred 787/799 items from pretrained weights
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks with YOLOv8n...
# AMP: checks passed ✅
# [rank3]:[W Utils.hpp:108] Warning: Environment variable NCCL_BLOCKING_WAIT is deprecated; use TORCH_NCCL_BLOCKING_WAIT instead (function getCvarString)
# [rank1]:[W Utils.hpp:108] Warning: Environment variable NCCL_BLOCKING_WAIT is deprecated; use TORCH_NCCL_BLOCKING_WAIT instead (function getCvarString)
# [rank0]:[W Utils.hpp:108] Warning: Environment variable NCCL_BLOCKING_WAIT is deprecated; use TORCH_NCCL_BLOCKING_WAIT instead (function getCvarString)
# [rank2]:[W Utils.hpp:108] Warning: Environment variable NCCL_BLOCKING_WAIT is deprecated; use TORCH_NCCL_BLOCKING_WAIT instead (function getCvarString)
# train: Scanning /work/ELSOLAR-3/train/labels... 13421 images, 0 backgrounds, 0 c
# train: New cache created: /work/ELSOLAR-3/train/labels.cache
# val: Scanning /work/ELSOLAR-3/valid/labels... 1821 images, 0 backgrounds, 0 corr
# val: New cache created: /work/ELSOLAR-3/valid/labels.cache
# Plotting labels to runs/detect/train4/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: SGD(lr=0.01, momentum=0.9) with parameter groups 129 weight(decay=0.0), 142 weight(decay=0.001), 141 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 32 dataloader workers
# Logging results to runs/detect/train4
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#       1/100      18.1G     0.8479      2.163      1.302      1.015      4.249
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1821       2660      0.755      0.507      0.599       0.41
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#       2/100      18.2G     0.5767     0.7952      1.018     0.7389     0.9207
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1821       2660        0.6      0.483       0.49      0.332
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#       3/100      18.2G     0.6216     0.7629      1.032     0.8393     0.9005
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1821       2660      0.528      0.237      0.165      0.126
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#       4/100      18.2G     0.6369     0.7864      1.045     0.8801     0.9419
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1821       2660      0.618      0.299      0.299      0.154
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#       5/100      18.2G     0.6022     0.7183      1.021     0.8228     0.8481
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1821       2660      0.605      0.564      0.565      0.348
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#       6/100      18.3G     0.5864     0.6658      1.008     0.8027     0.8046
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1821       2660       0.56      0.463      0.502      0.339
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#       7/100      18.2G     0.5539       0.63          1     0.7625     0.7362
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1821       2660      0.525      0.403      0.388       0.28
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#       8/100      18.2G     0.5347     0.6191      0.998     0.7439     0.7167
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1821       2660      0.603      0.473      0.463      0.325
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#       9/100      18.2G     0.5584     0.6309     0.9966     0.7621     0.7164
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1821       2660      0.633      0.632      0.586      0.392
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      10/100      18.2G     0.5285     0.5953     0.9884     0.7274      0.672
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1821       2660      0.672      0.613      0.644      0.446
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      11/100      18.2G     0.5404     0.5806     0.9798     0.7366      0.664
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1821       2660      0.769      0.593      0.645      0.423
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      12/100      18.2G     0.5333     0.5729     0.9805      0.731     0.6538
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1821       2660      0.747      0.521      0.574      0.374
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      13/100      18.2G     0.5326     0.5773     0.9784     0.7329     0.6526
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1821       2660      0.738      0.596      0.627      0.435
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      14/100      18.2G     0.5193     0.5593     0.9758     0.7082     0.6276
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1821       2660      0.713       0.61      0.634       0.45
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      15/100      18.2G     0.5162     0.5446     0.9769     0.7042     0.6103
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1821       2660      0.778      0.619      0.666      0.462
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      16/100      18.2G     0.5155     0.5486     0.9713     0.7009       0.61
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1821       2660      0.727      0.598      0.642       0.44
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      17/100      18.2G     0.4839     0.5239     0.9636     0.6587     0.5766
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1821       2660      0.762      0.645      0.657      0.455
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      18/100      18.2G     0.5191      0.534     0.9721     0.7022     0.5978
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1821       2660      0.664      0.666      0.658      0.443
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      19/100      18.2G     0.4905     0.5149     0.9647     0.6596     0.5646
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1821       2660      0.669      0.593      0.637       0.43
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      20/100      18.2G     0.4837     0.5043      0.959     0.6603     0.5467
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1821       2660      0.647      0.633      0.654      0.444
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      21/100      18.2G     0.5051     0.5195     0.9638     0.6818     0.5657
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1821       2660      0.864      0.632      0.673      0.481
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      22/100      18.2G     0.4883      0.503     0.9598     0.6599     0.5595
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1821       2660      0.853      0.616      0.667      0.458
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      23/100      18.2G     0.4912     0.5023      0.967     0.6557     0.5506
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1821       2660       0.76       0.68      0.683      0.472
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      24/100      18.2G     0.4962      0.491     0.9535     0.6619     0.5325
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1821       2660      0.795      0.692      0.724      0.489
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      25/100      18.2G     0.4991     0.4867     0.9579     0.6696     0.5356
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1821       2660      0.696      0.683      0.685      0.472
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      26/100      18.2G     0.4764     0.4834     0.9548     0.6341      0.531
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1821       2660      0.885      0.598      0.677      0.458
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      27/100      18.2G     0.4842     0.4837     0.9547     0.6509     0.5331
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1821       2660      0.798      0.605      0.648      0.445
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      28/100      18.2G     0.4851     0.4806     0.9519     0.6449     0.5142
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1821       2660      0.727      0.642       0.69      0.486
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      29/100      18.2G     0.4948     0.4851     0.9531     0.6563     0.5223
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1821       2660       0.79      0.607      0.669      0.468
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      30/100      18.2G     0.4765     0.4711      0.951     0.6339     0.5091
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1821       2660      0.787      0.692      0.689      0.487
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      31/100      18.2G     0.4759     0.4661     0.9534     0.6358     0.5037
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1821       2660      0.801        0.7      0.708      0.488
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      32/100      18.2G     0.4762     0.4602      0.949     0.6321     0.4965
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1821       2660      0.809      0.731      0.723      0.504
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      33/100      18.2G      0.481     0.4592     0.9456     0.6399     0.4929
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1821       2660      0.737      0.703      0.682      0.457
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      34/100      18.2G     0.4918     0.4708     0.9419     0.6512     0.5112
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1821       2660      0.783      0.669       0.69      0.481
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      35/100      18.2G     0.4662      0.451     0.9456     0.6211     0.4847
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1821       2660        0.9      0.623      0.698      0.478
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      36/100      18.2G     0.4668     0.4381     0.9428      0.623      0.474
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1821       2660       0.79      0.688      0.707      0.487
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      37/100      18.2G     0.4456     0.4235     0.9359     0.5928      0.449
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1821       2660      0.691      0.698       0.69      0.479
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      38/100      18.2G     0.4678     0.4516     0.9427     0.6201     0.4834
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1821       2660      0.805      0.702      0.731      0.508
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      39/100      18.2G     0.4583     0.4362     0.9426     0.6011     0.4622
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1821       2660      0.823      0.674      0.699      0.476
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      40/100      18.2G     0.4597      0.422     0.9378     0.6086     0.4455
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1821       2660      0.781       0.74      0.715      0.508
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      41/100      18.2G     0.4637     0.4285      0.935     0.6078     0.4476
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1821       2660      0.847      0.712      0.731      0.516
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      42/100      18.2G     0.4474     0.4166     0.9357     0.5905     0.4377
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1821       2660      0.742      0.717      0.725      0.502
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      43/100      18.2G     0.4284     0.4051     0.9369     0.5625     0.4179
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1821       2660      0.843      0.701      0.734      0.514
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      44/100      18.2G     0.4433     0.4105     0.9353     0.5838     0.4241
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1821       2660      0.872      0.689      0.745      0.516
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      45/100      18.2G     0.4474     0.4116     0.9332     0.5873     0.4337
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1821       2660      0.878      0.686      0.741      0.503
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      46/100      18.2G     0.4356     0.4108     0.9335     0.5734     0.4255
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1821       2660      0.873      0.718      0.756       0.52
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      47/100      18.3G     0.4457     0.4059      0.929     0.5896     0.4159
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1821       2660      0.786      0.696       0.74      0.515
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      48/100      18.2G     0.4343     0.4024     0.9326     0.5765     0.4236
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1821       2660      0.858      0.687      0.725      0.505
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      49/100      18.2G      0.435     0.3999     0.9286     0.5723      0.421
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1821       2660      0.884      0.723      0.752       0.53
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      50/100      18.2G     0.4269     0.3957      0.929     0.5603     0.4135
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1821       2660      0.847      0.709      0.737      0.518
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      51/100      18.2G      0.432     0.3904     0.9304     0.5677      0.406
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1821       2660      0.854      0.714      0.741      0.521
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      52/100      18.2G     0.4258     0.3797     0.9306     0.5577     0.3888
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1821       2660      0.874      0.712      0.743      0.512
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      53/100      18.2G     0.4364     0.3852     0.9317     0.5653     0.3943
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1821       2660      0.878      0.729      0.755      0.528
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      54/100      18.2G     0.4444     0.3925     0.9244     0.5765     0.4062
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1821       2660      0.863       0.73      0.753      0.525
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      55/100      18.2G     0.4446     0.3844      0.928     0.5813     0.3894
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1821       2660      0.783      0.707      0.735      0.517
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      56/100      18.2G     0.4152      0.372     0.9286     0.5384     0.3845
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1821       2660      0.891      0.691      0.743      0.524
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      57/100      18.2G     0.4193     0.3812     0.9269     0.5489     0.3858
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1821       2660      0.872      0.716      0.751      0.525
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      58/100      18.2G     0.4051     0.3624     0.9307     0.5292     0.3767
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1821       2660      0.889      0.719      0.752       0.53
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      59/100      18.2G     0.4037     0.3573     0.9223      0.528     0.3683
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1821       2660      0.898      0.721      0.756      0.527
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      60/100      18.2G     0.4102     0.3632     0.9217     0.5391     0.3701
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1821       2660      0.891      0.691      0.752      0.505
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      61/100      18.2G     0.4138     0.3649     0.9251     0.5347     0.3758
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1821       2660       0.91      0.724      0.756      0.528
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      62/100      18.2G     0.4206     0.3648     0.9275     0.5495     0.3759
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1821       2660      0.896      0.727      0.759      0.536
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      63/100      18.2G     0.3913     0.3451     0.9195     0.5044     0.3495
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1821       2660      0.894      0.723      0.756      0.537
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      64/100      18.2G     0.3948       0.35     0.9198     0.5084     0.3547
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1821       2660      0.908      0.727      0.762      0.541
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      65/100      18.2G     0.4038      0.351     0.9208     0.5212     0.3615
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1821       2660      0.874      0.713      0.754      0.529
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      66/100      18.2G     0.3916     0.3434     0.9185     0.5055     0.3531
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1821       2660      0.909      0.727      0.764      0.542
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      67/100      18.2G       0.41     0.3492     0.9212     0.5302     0.3611
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1821       2660      0.896      0.721       0.76      0.528
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      68/100      18.2G     0.4058     0.3498     0.9223     0.5197     0.3557
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1821       2660      0.794      0.789      0.805      0.572
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      69/100      18.2G     0.3935     0.3323     0.9154     0.5077     0.3382
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1821       2660      0.896      0.728      0.774      0.548
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      70/100      18.2G     0.3827     0.3247     0.9119     0.4926     0.3275
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1821       2660      0.886      0.734       0.76      0.524
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      71/100      18.2G     0.4052     0.3385     0.9128     0.5184     0.3409
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1821       2660      0.892      0.724      0.759      0.521
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      72/100      18.2G     0.3929     0.3324     0.9157     0.5026     0.3341
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1821       2660      0.815      0.726      0.758      0.525
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      73/100      18.2G     0.3931     0.3309     0.9132     0.4961     0.3322
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1821       2660      0.895      0.736      0.763      0.524
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      74/100      18.2G     0.3962     0.3283      0.914     0.5144     0.3313
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1821       2660      0.907      0.724       0.76      0.521
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      75/100      18.2G     0.3703     0.3083       0.91     0.4802     0.3097
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1821       2660      0.896      0.729      0.759      0.516
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      76/100      18.2G     0.3587     0.3159     0.9111     0.4589     0.3173
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1821       2660      0.907      0.726       0.76      0.527
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      77/100      18.2G     0.3665     0.3173     0.9095     0.4748     0.3231
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1821       2660      0.822       0.71      0.756      0.523
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      78/100      18.2G     0.3767     0.3221     0.9097     0.4832     0.3268
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1821       2660      0.889       0.72      0.757       0.53
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      79/100      18.2G     0.3713     0.3095     0.9103      0.472     0.3132
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1821       2660      0.883      0.722      0.751      0.525
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      80/100      18.2G     0.3575     0.2953     0.9023     0.4527     0.2919
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1821       2660      0.897      0.727      0.758      0.525
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      81/100      18.2G     0.3603      0.294     0.9052     0.4586     0.2924
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1821       2660      0.886       0.73      0.757      0.528
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      82/100      18.2G     0.3618     0.2928     0.9022     0.4587      0.292
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1821       2660      0.892      0.726      0.757      0.525
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      83/100      18.2G     0.3553     0.2907     0.9044     0.4508     0.2953
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1821       2660      0.894      0.732      0.762      0.525
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      84/100      18.2G     0.3416     0.2848     0.9062      0.433     0.2868
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1821       2660      0.904      0.718      0.758      0.523
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      85/100      18.2G     0.3452     0.2783     0.9056     0.4351     0.2792
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1821       2660        0.9      0.727      0.758      0.531
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      86/100      18.2G      0.344     0.2743     0.8965     0.4353     0.2733
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1821       2660      0.898      0.734       0.76      0.536
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      87/100      18.3G     0.3488     0.2795     0.8936     0.4408      0.273
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1821       2660      0.903      0.738      0.761      0.532
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      88/100      18.2G     0.3365     0.2727     0.8992     0.4232     0.2651
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1821       2660      0.819      0.727      0.757       0.53
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      89/100      18.3G     0.3518      0.281     0.9003     0.4404     0.2761
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1821       2660      0.914      0.722      0.759       0.53
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      90/100      18.2G     0.3352      0.264      0.898     0.4211     0.2568
