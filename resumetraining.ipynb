# %%
# !pip install -q supervision
# !pip install ultralytics
# !pip install -q git+https://github.com/THU-MIG/yolov10.git
# !pip install huggingface_hub
# Out:
# [notice] A new release of pip is available: 24.1.1 -> 24.1.2
# [notice] To update, run: pip install --upgrade pip
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.2/41.2 kB 7.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 13.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 802.9/802.9 kB 61.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 131.3 MB/s eta 0:00:0000:010:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.5/62.5 MB 78.4 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 kB 62.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 779.1/779.1 MB 8.6 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 16.6 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 137.8 MB/s eta 0:00:0000:010:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 61.2 MB/s eta 0:00:0000:0100:01m
# ...

# %%
import os

os.environ['WANDB_MODE'] = 'disabled'
os.environ["OMP_NUM_THREADS"] = "16"

# %%
# !yolo task=detect mode=val model='runs/detect/train4/weights/last.pt'  data='/work/ELSOLAR-3/data.yaml' device=0,1,2,3
# Out:
# Ultralytics YOLOv8.1.34 🚀 Python-3.10.14 torch-2.3.1+cu121 CUDA:0 (Tesla V100-SXM2-32GB, 32494MiB)
#                                                             CUDA:1 (Tesla V100-SXM2-32GB, 32494MiB)
#                                                             CUDA:2 (Tesla V100-SXM2-32GB, 32494MiB)
#                                                             CUDA:3 (Tesla V100-SXM2-32GB, 32494MiB)
# YOLOv10m summary (fused): 369 layers, 16466596 parameters, 0 gradients, 63.5 GFLOPs
# val: Scanning /work/ELSOLAR-3/valid/labels.cache... 1821 images, 0 backgrounds,
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1821       2660      0.905      0.732      0.759      0.533
#             black_core       1821        205      0.968      0.946      0.964       0.92
#                  crack       1821        383       0.73      0.663      0.691      0.443
# ...

# %%
# !yolo task=detect mode=val model='runs/detect/train4/ELSOLARbest.pt'  data='/work/ELSOLAR-3/data.yaml' device=0,1,2,3
# Out:
# Ultralytics YOLOv8.1.34 🚀 Python-3.10.14 torch-2.3.1+cu121 CUDA:0 (Tesla V100-SXM2-32GB, 32494MiB)
#                                                             CUDA:1 (Tesla V100-SXM2-32GB, 32494MiB)
#                                                             CUDA:2 (Tesla V100-SXM2-32GB, 32494MiB)
#                                                             CUDA:3 (Tesla V100-SXM2-32GB, 32494MiB)
# YOLOv10m summary (fused): 369 layers, 16466596 parameters, 0 gradients, 63.5 GFLOPs
# val: Scanning /work/ELSOLAR-3/valid/labels.cache... 1821 images, 0 backgrounds,
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all       1821       2660      0.794      0.788      0.805      0.572
#             black_core       1821        205      0.953      0.941      0.966      0.919
#                  crack       1821        383      0.646      0.734      0.705      0.468
# ...

# %%
# !nvidia-smi
# Out:
# Fri Jul 19 00:00:16 2024
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla V100-SXM2-32GB           Off |   00000000:18:00.0 Off |                    0 |
# | N/A   32C    P0             42W /  300W |       0MiB /  32768MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...
